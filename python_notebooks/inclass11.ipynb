# %%
#Making altiar plots to save to Jekyll

# %%
1+1
# Out:
# 2

# %%
#Go to Vega Editor
#Export figure as JSON Vega_Lite and check include config. Do NOT use compiled Vega

# %%
#Prep Notebook week 11 has Vega dataset.

# %%
#I can download a JSON specification from 
# the Vega Editor (https://vega.githuv.id/editor/) and 
# save it in "assets/json" folder

# %%
#See the project 2 in the projects folder
